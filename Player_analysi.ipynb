# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
from pandas.plotting import table 
# !pip install xlwt

# %%
players_stats = pd.read_csv('data/players_stats.csv',sep=';')

# %%
players_stats
# Out:
#           id    player  player_team  s1 opponent  s2  rating2.0   map  \
# 0      11893     zywoo     Vitality  10  AVANGAR  16       1.04    d2
# 1      11893     zywoo     Vitality  16  AVANGAR  11       1.63   inf
# 2      11893     zywoo     Vitality   9  AVANGAR  16       0.90   mrg
# 3      11893     zywoo     Vitality  16     MOUZ  10       1.52   mrg
# 4      11893     zywoo     Vitality  16     MOUZ   5       1.44   vtg
# ...      ...       ...          ...  ..      ...  ..        ...   ...
# 42981  13461  wannafly  Lucid Dream  16     NASR   1       1.17    d2
# 42982  13461  wannafly  Lucid Dream  16     NASR   9       1.60  nuke
# 42983  13461  wannafly  Lucid Dream   8     NASR  16       0.79   ovp
# 42984  13461  wannafly  Lucid Dream  16   Entity   1       1.23   mrg
# 42985  13461  wannafly  Lucid Dream  16   Entity   5       1.54  nuke
#
#              date event_type event_tier  team_rank  opponent_rank  \
# ...

# %%
players_stats.to_excel('data/excel.xls',index=False)
# Out:
# C:\Users\Botelho\AppData\Local\Temp\ipykernel_18856\1068513867.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   players_stats.to_excel('data/excel.xls',index=False)

# %%
players_stats.groupby(by = 'player').mean()
# Out:
#               id         s1         s2  rating2.0  team_rank  opponent_rank  \
# player
# 1962     12094.0  13.840000  12.120000   1.066640  35.000000      31.568000
# ablej    16770.0  14.341584  11.297030   1.017475  16.272277      26.871287
# adren      334.0  13.986175  12.677419   0.970691  12.184332      21.824885
# advent    8600.0  13.780749  12.299465   0.874439  29.443850      29.149733
# aerial    4076.0  13.754491  12.467066   1.072395   8.365269      17.532934
# ...          ...        ...        ...        ...        ...            ...
# zeus       484.0  14.157895  12.936842   0.946105   6.105263      14.136842
# zews      6608.0  11.523810  14.238095   0.726190  14.047619      11.952381
# zewsy     8764.0  13.921687  11.222892   1.117711  35.000000      32.506024
# zhoking   8601.0  13.825397  12.328042   1.114180  29.502646      29.211640
# zywoo    11893.0  14.322222  11.770370   1.348333   8.366667      18.800000
#
# ...

# %%
players_stats.groupby(by = 'player_team').mean().query('player_team == "Astralis"')
# Out:
#                  id         s1         s2  rating2.0  team_rank  \
# player_team
# Astralis     7277.6  15.188679  11.037736   1.175233   1.993711
#
#              opponent_rank  rank_difference  favorite  round_difference  \
# player_team
# Astralis         14.301887       -12.308176  0.937107          4.150943
#
#                   win  team_rating
# player_team
# Astralis     0.742138     1.175233

# %%
players_stats.describe()
# Out:
#                  id            s1            s2     rating2.0     team_rank  \
# count  42986.000000  42986.000000  42986.000000  42986.000000  42986.000000
# mean    9379.163169     13.889871     12.481948      1.101957     21.771996
# std     3909.155608      4.104788      4.773342      0.329508     11.490875
# min       29.000000      0.000000      0.000000      0.140000      1.000000
# 25%     7716.000000     12.000000      9.000000      0.880000     12.000000
# 50%     9217.000000     16.000000     14.000000      1.080000     23.000000
# 75%    12030.000000     16.000000     16.000000      1.300000     35.000000
# max    19645.000000     34.000000     34.000000      2.830000     35.000000
#
#        opponent_rank  rank_difference  round_difference   team_rating
# count   42986.000000     42986.000000      42986.000000  42986.000000
# mean       24.502675        -2.730680          1.407924      1.101957
# std        11.732407        11.983199          7.210974      0.247754
# ...

# %%
players_stats.groupby(by='win').count()
# Out:
#           id  player  player_team     s1  opponent     s2  rating2.0    map  \
# win
# False  17892   17892        17892  17892     17892  17892      17892  17892
# True   25094   25094        25094  25094     25094  25094      25094  25094
#
#         date  event_type  event_tier  team_rank  opponent_rank  \
# win
# False  17892       17892       17892      17892          17892
# True   25094       25094       25094      25094          25094
#
#        rank_difference  favorite  round_difference  team_rating
# win
# False            17892     17892             17892        17892
# True             25094     25094             25094        25094

# %%
players_stats.groupby(by='favorite').mean()
# Out:
#                    id         s1         s2  rating2.0  team_rank  \
# favorite
# False     9920.433590  13.273705  13.128652   1.065339  28.171222
# True      8794.790131  14.555104  11.783745   1.141492  14.863183
#
#           opponent_rank  rank_difference  round_difference       win  \
# favorite
# False         22.344058         5.827164          0.145053  0.501344
# True          26.833188       -11.970005          2.771359  0.672762
#
#           team_rating
# favorite
# False        1.065339
# True         1.141492

# %%
players_stats[~(players_stats['round_difference'] < - 6) | (players_stats['round_difference'] >  4)].describe()
# Out:
#                  id            s1            s2     rating2.0     team_rank  \
# count  35788.000000  35788.000000  35788.000000  35788.000000  35788.000000
# mean    9417.839974     15.389740     11.774366      1.168512     21.635716
# std     3887.641967      2.415533      4.937362      0.304319     11.532062
# min       29.000000     10.000000      0.000000      0.250000      1.000000
# 25%     7716.000000     15.000000      8.000000      0.950000     12.000000
# 50%     9220.000000     16.000000     12.000000      1.140000     23.000000
# 75%    12088.000000     16.000000     16.000000      1.350000     35.000000
# max    19645.000000     34.000000     34.000000      2.830000     35.000000
#
#        opponent_rank  rank_difference  round_difference   team_rating
# count   35788.000000     35788.000000      35788.000000  35788.000000
# mean       25.413351        -3.777635          3.615374      1.168378
# std        11.368520        11.548731          5.690965      0.208053
# ...
