# %% [markdown]
# # Importing modules

# %%
from mediawiki import MediaWiki
import regex as re
import pandas as pd
from liquipediapy import counterstrike
import numpy as np
import os
from dotenv import load_dotenv
import time
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Using liquipediapy

# %%
csgo_apy = counterstrike(f"Data_gathering({os.getenv('email')})")

# %%
csgo_tournaments = csgo_apy.get_tournaments('Premier')
csgo_players = csgo_apy.get_players()

# %% [markdown]
# ## Using MediaWiki

# %%
csgo_media = MediaWiki(url = 'https://liquipedia.net/counterstrike/api.php',timeout = 60
                       ,user_agent=f"Data_gathering({os.getenv('email')})")

# %% [markdown]
# # Creating tables

# %%
tournaments_df = pd.DataFrame(csgo_tournaments)
tournaments_df_clean = tournaments_df.copy()
tournaments_df_clean
# Out:
#     tier                            tournament                   date  \
# 0                    BLAST.tv Paris Major 2023      May 08 - 21, 2023
# 1              BLAST Premier: World Final 2022      Dec 14 - 18, 2022
# 2              BLAST Premier: Fall Finals 2022      Nov 23 - 27, 2022
# 3                     Elisa Masters Espoo 2022      Nov 16 - 20, 2022
# 4         Intel Extreme Masters Rio Major 2022  Oct 31 - Nov 13, 2022
# ..   ...                                   ...                    ...
# 213                      DreamHack Winter 2012      Nov 22 - 24, 2012
# 214                                  ESWC 2012  Oct 31 - Nov 04, 2012
# 215                      DreamHack Summer 2012      Jun 16 - 20, 2012
# 216                   Intel Extreme Masters VI      Mar 06 - 10, 2012
# 217               IEM VI Global Challenge Kiev      Jan 19 - 22, 2012
#
#           prize teams_no           host_locaion    event_locaion first_place  \
# 0    $1,250,000       24                 France            Paris         TBD
# 1    $1,000,000        8   United Arab Emirates        Abu Dhabi         TBD
# 2      $425,000        8                Denmark       Copenhagen         TBD
# 3      $200,000       12                Finland            Espoo         TBD
# 4    $1,000,000       24                 Brazil   Rio de Janeiro         TBD
# ..          ...      ...                    ...              ...         ...
# 213  $45,275.16       16                 Sweden      Jönköping         NiP
# 214     $22,000       10                 France            Paris         NiP
# 215  $14,221.70        8                 Sweden      Jönköping      Fnatic
# 216    $100,000       12                Germany         Hannover         ESC
# 217     $40,000        8                Ukraine             Kiev       Na`Vi
#
#     second_place
# 0            TBD
# 1            TBD
# 2            TBD
# 3            TBD
# 4            TBD
# ..           ...
# 213           VG
# 214           VG
# 215        Na`Vi
# 216        Na`Vi
# 217           SK
#
# [218 rows x 9 columns]

# %%
players_df = pd.DataFrame(csgo_players)
players_df
# Out:
#            id                 name       country team
# 0      stikle                            Albania
# 1     chrissK       ChristophKröll       Austria
# 2     dukiiii          DukiIvkovic       Austria
# 3      kakafu  AlexanderSzymanczyk       Austria
# 4     NinoZjE            AnelZukić       Austria
# ...       ...                  ...           ...  ...
# 1834   ZipZip            RikusKlue  South Africa
# 1835    Potei      AlaeddineChaari       Tunisia
# 1836   Remind        AdelGuermassi       Tunisia
# 1837    Sheva       HatemGuermassi       Tunisia
# 1838     torr       MohamedHamdani       Tunisia
#
# [1839 rows x 4 columns]

# %% [markdown]
# ## Cleaning tables - Tournament

# %% [markdown]
# ### Tier

# %%
tournaments_df_clean = tournaments_df.drop('tier',axis = 1)

# %% [markdown]
# ### Date

# %%
tournaments_df_clean['date'] = tournaments_df['date'].str.replace('(.*-) .*, ([0-9]*)','\\1 \\2',regex = True)
tournaments_df_clean.loc[tournaments_df_clean['date'] == 'Mar\xa0??, 2020','date'] = 'Mar 15 - 2020'#tournaments_df_clean[tournaments_df_clean['date'] == 'Mar\xa0??, 2020']['date'].str.replace('[??].','15',regex = True)
tournaments_df_clean['date'] = pd.to_datetime(tournaments_df_clean['date'].str.lower(), format = '%b %d - %Y') # Dec 14 - 2022

# %% [markdown]
# ### Prize

# %%
tournaments_df_clean['prize'] = tournaments_df['prize'].str.replace('\$','',regex = True)
tournaments_df_clean['prize'] = tournaments_df_clean['prize'].str.replace(',','',regex = True)
tournaments_df_clean['prize'] = pd.to_numeric(tournaments_df_clean['prize'])

# %% [markdown]
# ### Team No

# %%
tournaments_df_clean['teams_no'] = pd.to_numeric(tournaments_df['teams_no'])

# %% [markdown]
# ### Host and Event Location

# %%
tournaments_df_clean = tournaments_df_clean.rename({'host_locaion':'host_location',	'event_locaion':'event_location'})

# %%
tournaments_df_clean
# Out:
#                                tournament       date       prize  teams_no  \
# 0               BLAST.tv Paris Major 2023 2023-05-08  1250000.00        24
# 1         BLAST Premier: World Final 2022 2022-12-14  1000000.00         8
# 2         BLAST Premier: Fall Finals 2022 2022-11-23   425000.00         8
# 3                Elisa Masters Espoo 2022 2022-11-16   200000.00        12
# 4    Intel Extreme Masters Rio Major 2022 2022-10-31  1000000.00        24
# ..                                    ...        ...         ...       ...
# 213                 DreamHack Winter 2012 2012-11-22    45275.16        16
# 214                             ESWC 2012 2012-10-31    22000.00        10
# 215                 DreamHack Summer 2012 2012-06-16    14221.70         8
# 216              Intel Extreme Masters VI 2012-03-06   100000.00        12
# 217          IEM VI Global Challenge Kiev 2012-01-19    40000.00         8
#
#               host_locaion    event_locaion first_place second_place
# 0                   France            Paris         TBD          TBD
# 1     United Arab Emirates        Abu Dhabi         TBD          TBD
# 2                  Denmark       Copenhagen         TBD          TBD
# 3                  Finland            Espoo         TBD          TBD
# 4                   Brazil   Rio de Janeiro         TBD          TBD
# ..                     ...              ...         ...          ...
# 213                 Sweden      Jönköping         NiP           VG
# 214                 France            Paris         NiP           VG
# 215                 Sweden      Jönköping      Fnatic        Na`Vi
# 216                Germany         Hannover         ESC        Na`Vi
# 217                Ukraine             Kiev       Na`Vi           SK
#
# [218 rows x 8 columns]

# %% [markdown]
# ## Cleaning players table

# %%
players_df_clean = players_df.copy()
players_df_clean = players_df_clean.drop('team', axis = 1)

# %% [markdown]
# ### Name

# %%
players_df_clean['name'] = players_df['name'].str.lower().str.strip()

# %% [markdown]
# ### id

# %%
players_df_clean['id'] = players_df['id'].str.lower()

# %%
players_df_clean
# Out:
#            id                 name       country
# 0      stikle                            Albania
# 1     chrissk       christophkröll       Austria
# 2     dukiiii          dukiivkovic       Austria
# 3      kakafu  alexanderszymanczyk       Austria
# 4     ninozje            anelzukić       Austria
# ...       ...                  ...           ...
# 1834   zipzip            rikusklue  South Africa
# 1835    potei      alaeddinechaari       Tunisia
# 1836   remind        adelguermassi       Tunisia
# 1837    sheva       hatemguermassi       Tunisia
# 1838     torr       mohamedhamdani       Tunisia
#
# [1839 rows x 3 columns]

# %% [markdown]
# # Creating Tournaments 2019

# %%
tournaments_2019 = tournaments_df_clean[tournaments_df_clean['date'].dt.year == 2019]
tournaments_2019.reset_index(drop = True,inplace = True)
tournaments_2019
# Out:
#                                           tournament       date      prize  \
# 0                                     EPICENTER 2019 2019-12-17   500000.0
# 1                BLAST Pro Series: Global Final 2019 2019-12-12   500000.0
# 2                  ESL Pro League Season 10 - Finals 2019-12-03   600000.0
# 3      Esports Championship Series Season 8 - Finals 2019-11-28   500000.0
# 4                      CS:GO Asia Championships 2019 2019-11-20   500000.0
# 5                  ESL Pro League Season 10 - Europe 2019-10-08    60000.0
# 6                ESL Pro League Season 10 - Americas 2019-10-08    62000.0
# 7                Intel Extreme Masters XIV - Beijing 2019-11-07   250000.0
# 8               StarSeries & i-League CS:GO Season 8 2019-10-21   500000.0
# 9                       DreamHack Masters Malmö 2019 2019-10-01   250000.0
# 10                            ESL One: New York 2019 2019-09-26   200000.0
# 11                      StarLadder Berlin Major 2019 2019-08-23  1000000.0
# 12               Intel Extreme Masters XIV - Chicago 2019-07-18   250000.0
# 13                             ESL One: Cologne 2019 2019-07-02   300000.0
# 14                  ESL Pro League Season 9 - Finals 2019-06-18   600000.0
# 15     Esports Championship Series Season 7 - Finals 2019-06-06   500000.0
# 16                     DreamHack Masters Dallas 2019 2019-05-28   250000.0
# 17                  ESL Pro League Season 9 - Europe 2019-04-12    60000.0
# 18                ESL Pro League Season 9 - Americas 2019-04-12    62000.0
# 19                Intel Extreme Masters XIV - Sydney 2019-04-29   250000.0
# 20              StarSeries & i-League CS:GO Season 7 2019-03-30   500000.0
# 21                World Electronic Sports Games 2018 2019-03-11   890000.0
# 22  Intel Extreme Masters XIII - Katowice Major 2019 2019-02-13  1000000.0
#
#     teams_no     host_locaion     event_locaion first_place second_place
# 0          8           Russia            Moscow    Vitality         mouz
# 1          4          Bahrain             Riffa    Astralis         FaZe
# 2         16          Denmark            Odense        mouz       Fnatic
# 3          8    United States         Arlington    Astralis       Liquid
# 4          8            China          Shanghai        mouz         ENCE
# 5         16   United Kingdom            London         TBD          TBD
# 6         16    United States           Burbank         TBD          TBD
# 7          8            China   Beijing-Haidian    Astralis         100T
# 8         16           Turkey             Belek          EG       Fnatic
# 9         16           Sweden            Malmö      Fnatic     Vitality
# 10         8    United States     New York City          EG     Astralis
# 11        24          Germany            Berlin    Astralis          AVG
# 12         8    United States           Chicago      Liquid         ENCE
# 13        16          Germany           Cologne      Liquid     Vitality
# 14        16           France       Montpellier      Liquid           G2
# 15         8   United Kingdom            London    Vitality        FURIA
# 16        16    United States            Dallas      Liquid         ENCE
# 17        16   United Kingdom         Leicester         TBD          TBD
# 18        16    United States           Burbank         TBD          TBD
# 19        16        Australia            Sydney      Liquid       Fnatic
# 20        16            China          Shanghai       Na`Vi       Fnatic
# 21        27            China         Chongqing     Windigo          AGO
# 22        24           Poland          Katowice    Astralis         ENCE

# %% [markdown]
# ## Cleaning Tournaments 2019

# %% [markdown]
# ### Removing qualifiers and local tournaments

# %%
tournaments_2019 = tournaments_2019[tournaments_2019['first_place'] != 'TBD']
tournaments_2019 = tournaments_2019[tournaments_2019['first_place'] != 'Windigo']

# %% [markdown]
# ### Removing lower prizer (<250.000)

# %%
tournaments_2019 = tournaments_2019[tournaments_2019['prize']>250000].reset_index(drop = True)

# %%
tournaments_2019
# Out:
#                                           tournament       date      prize  \
# 0                                     EPICENTER 2019 2019-12-17   500000.0
# 1                BLAST Pro Series: Global Final 2019 2019-12-12   500000.0
# 2                  ESL Pro League Season 10 - Finals 2019-12-03   600000.0
# 3      Esports Championship Series Season 8 - Finals 2019-11-28   500000.0
# 4                      CS:GO Asia Championships 2019 2019-11-20   500000.0
# 5               StarSeries & i-League CS:GO Season 8 2019-10-21   500000.0
# 6                       StarLadder Berlin Major 2019 2019-08-23  1000000.0
# 7                              ESL One: Cologne 2019 2019-07-02   300000.0
# 8                   ESL Pro League Season 9 - Finals 2019-06-18   600000.0
# 9      Esports Championship Series Season 7 - Finals 2019-06-06   500000.0
# 10              StarSeries & i-League CS:GO Season 7 2019-03-30   500000.0
# 11  Intel Extreme Masters XIII - Katowice Major 2019 2019-02-13  1000000.0
#
#     teams_no     host_locaion event_locaion first_place second_place
# 0          8           Russia        Moscow    Vitality         mouz
# 1          4          Bahrain         Riffa    Astralis         FaZe
# 2         16          Denmark        Odense        mouz       Fnatic
# 3          8    United States     Arlington    Astralis       Liquid
# 4          8            China      Shanghai        mouz         ENCE
# 5         16           Turkey         Belek          EG       Fnatic
# 6         24          Germany        Berlin    Astralis          AVG
# 7         16          Germany       Cologne      Liquid     Vitality
# 8         16           France   Montpellier      Liquid           G2
# 9          8   United Kingdom        London    Vitality        FURIA
# 10        16            China      Shanghai       Na`Vi       Fnatic
# 11        24           Poland      Katowice    Astralis         ENCE

# %% [markdown]
# # Gathering more data from 2019

# %%
tournaments_2019
# Out:
#                                           tournament       date      prize  \
# 0                                     EPICENTER 2019 2019-12-17   500000.0
# 1                BLAST Pro Series: Global Final 2019 2019-12-12   500000.0
# 2                  ESL Pro League Season 10 - Finals 2019-12-03   600000.0
# 3      Esports Championship Series Season 8 - Finals 2019-11-28   500000.0
# 4                      CS:GO Asia Championships 2019 2019-11-20   500000.0
# 5               StarSeries & i-League CS:GO Season 8 2019-10-21   500000.0
# 6                       StarLadder Berlin Major 2019 2019-08-23  1000000.0
# 7                              ESL One: Cologne 2019 2019-07-02   300000.0
# 8                   ESL Pro League Season 9 - Finals 2019-06-18   600000.0
# 9      Esports Championship Series Season 7 - Finals 2019-06-06   500000.0
# 10              StarSeries & i-League CS:GO Season 7 2019-03-30   500000.0
# 11  Intel Extreme Masters XIII - Katowice Major 2019 2019-02-13  1000000.0
#
#     teams_no     host_locaion event_locaion first_place second_place
# 0          8           Russia        Moscow    Vitality         mouz
# 1          4          Bahrain         Riffa    Astralis         FaZe
# 2         16          Denmark        Odense        mouz       Fnatic
# 3          8    United States     Arlington    Astralis       Liquid
# 4          8            China      Shanghai        mouz         ENCE
# 5         16           Turkey         Belek          EG       Fnatic
# 6         24          Germany        Berlin    Astralis          AVG
# 7         16          Germany       Cologne      Liquid     Vitality
# 8         16           France   Montpellier      Liquid           G2
# 9          8   United Kingdom        London    Vitality        FURIA
# 10        16            China      Shanghai       Na`Vi       Fnatic
# 11        24           Poland      Katowice    Astralis         ENCE

# %% [markdown]
# ## Creating the tables of competing players in 2019

# %%
players = []
tournaments_players = {}
for tournament in tournaments_2019['tournament']:
    time.sleep(5)
    # Usa api para fazer um search
    lista = csgo_media.search(tournament,results = 20)
    # Limpa a lista de search para remover aquilo que não é o link para o evento
    links = ['https://liquipedia.net/counterstrike/'+link for link in lista if link[-1].isdigit() or len(re.findall('Season [0-9]$',link))>0 or len(re.findall('Final',link))>0 or len(re.findall('Cologne$',link))>0 or len(re.findall('Major',link))>0 or len(re.findall('Championship',link))>0 ]
    # Adiciona os links possiveis para o torneio 
    link_url = [link for link in links if len(re.findall('Minor',link)) == 0 and len(re.findall('Open',link)) == 0]
    #Cria todas as tabelas da pagina do torneio
    tabelas = pd.read_html(link_url[0].replace(' ','_'))
    players_tournaments = []
    #Procura nas tabelas por todas aquelas que contem jogadores
    for tabela in tabelas:
        if (tabela.shape == (6,2) or tabela.shape == (5,2)) and np.all(tabela.columns == [0,1]):
            players.append(list(tabela[1][0:5]))
            players_tournaments.append(list(tabela[1][0:5]))
            tournaments_players[tournament.replace(' ','_').lower()] = players_tournaments
            if int(tournaments_2019[tournaments_2019['tournament'] == tournament]['teams_no']) == len(players_tournaments):
                break

# %%
#Cria uma lista de jogares que atuaram nos torneios de 2019
players_2019 = [player.lower() for teams in players for player in teams]
players_2019 = list(dict.fromkeys(players_2019))
#Cria o data frame usando informação de todos os jogadores em atividade
players_2019_df = players_df_clean[players_df_clean['id'].isin(players_2019)].reset_index(drop=True)
#Adiciona os players não presentes na lista geral que ja se aposentaram
for retire_player in players_2019:
    if retire_player in (list(players_2019_df['id'])):
        pass
    else:
        players_2019_df.loc[len(players_2019_df.index)] = [retire_player,'','']
# Out:
#             id                        name                 country
# 0         keoz                 nicolasdgus                 Belgium
# 1         niko                 nikolakovač  Bosnia and Herzegovina
# 2         cerq  tsvetelindimitrovmangalski                Bulgaria
# 3        oskar                tomáššťastný          Czech Republic
# 4        twist                 matějpetráš          Czech Republic
# ..         ...                         ...                     ...
# 241    n0thing
# 242    deadfox
# 243      fugly
# 244  worldedit
# 245  waylander
#
# [246 rows x 3 columns]

# %% [markdown]
# ## Creating the conection between Players and tournament

# %%
dic_tournaments_players = {}
for key in tournaments_players.keys():
    dic_tournaments_players[key] = np.array(tournaments_players[key]).flatten()

df_tournaments_players = pd.DataFrame(pd.Series(dic_tournaments_players)).reset_index().explode(0)

df_tournaments_players = df_tournaments_players.rename(columns={0:'player','index':'tournament'}).reset_index(drop= True)
# Out:
#                                            tournament      player
# 0                                      epicenter_2019      flamie
# 1                                      epicenter_2019      s1mple
# 2                                      epicenter_2019  electronic
# 3                                      epicenter_2019     Boombl4
# 4                                      epicenter_2019    GuardiaN
# ..                                                ...         ...
# 815  intel_extreme_masters_xiii_-_katowice_major_2019     zhokiNg
# 816  intel_extreme_masters_xiii_-_katowice_major_2019     Freeman
# 817  intel_extreme_masters_xiii_-_katowice_major_2019       aumaN
# 818  intel_extreme_masters_xiii_-_katowice_major_2019      advent
# 819  intel_extreme_masters_xiii_-_katowice_major_2019        kaze
#
# [820 rows x 2 columns]

# %%
for retire_player in players_2019:
    if retire_player in (list(players_2019_df['id'])):
        pass
    else:
        print(retire_player)
# Out:
# rpk
# 4king
# equal
# device
# hunter-
# jugi
# kngv-
# ethan
# leo_drunky
# dickstacy
# somebody
# zeus
# zews
# get_right
# nbk-
# zellsis
# ange1
# issaa
# lowel
# nukkye
# dephh
# shahzam
# sick
# ablej
# ramz1kbo$$
# gob b
# zeff
# xeta
# stax
# hsk
# vice
# nex
# coldy
# somedieyoung
# hz
# n0thing
# deadfox
# fugly
# worldedit
# waylander

# %%
# Out:
# C:\Users\Botelho\AppData\Local\Temp\ipykernel_22864\3815423309.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   players_2019_df.append(pd.DataFrame(add_player, columns=['id','name','country'])).reset_index(drop=True)
#             id                        name                 country
# 0         keoz                 nicolasdgus                 Belgium
# 1         niko                 nikolakovač  Bosnia and Herzegovina
# 2         cerq  tsvetelindimitrovmangalski                Bulgaria
# 3        oskar                tomáššťastný          Czech Republic
# 4        twist                 matějpetráš          Czech Republic
# ..         ...                         ...                     ...
# 241    n0thing
# 242    deadfox
# 243      fugly
# 244  worldedit
# 245  waylander
#
# [246 rows x 3 columns]

# %% [markdown]
# # CSV

# %%
tournaments_2019.reset_index(drop = True).to_csv('data/tournaments_2019.csv',sep=';')
df_tournaments_players.reset_index(drop = True).to_csv('data/tournaments_players.csv',sep=';')
players_2019_df.reset_index(drop = True).to_csv('data/players_2019.csv',sep=';')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\Botelho\OneDrive\Documentos\Ironhack\Projetos\CSGO_Player_Perfomance\Data_Gathering.ipynb Cell 48 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Botelho/OneDrive/Documentos/Ironhack/Projetos/CSGO_Player_Perfomance/Data_Gathering.ipynb#X65sZmlsZQ%3D%3D?line=0'>1</a> tournaments_2019.reset_index(drop = True).to_csv('data/tournaments_2019.csv',sep=';')
#       <a href='vscode-notebook-cell:/c%3A/Users/Botelho/OneDrive/Documentos/Ironhack/Projetos/CSGO_Player_Perfomance/Data_Gathering.ipynb#X65sZmlsZQ%3D%3D?line=1'>2</a> df_tournaments_players.reset_index(drop = True).to_csv('data/tournaments_players.csv',sep=';')
#       <a href='vscode-notebook-cell:/c%3A/Users/Botelho/OneDrive/Documentos/Ironhack/Projetos/CSGO_Player_Perfomance/Data_Gathering.ipynb#X65sZmlsZQ%3D%3D?line=2'>3</a> players_2019_df.reset_index(drop = True).to_csv('data/players_2019.csv',sep=';')
#
# File c:\Users\Botelho\anaconda3\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
#    3556     errors=errors,
#    3557     compression=compression,
#    3558     quoting=quoting,
#    3559     columns=columns,
#    3560     index_label=index_label,
#    3561     mode=mode,
#    3562     chunksize=chunksize,
#    3563     quotechar=quotechar,
#    3564     date_format=date_format,
#    3565     doublequote=doublequote,
#    3566     escapechar=escapechar,
#    3567     storage_options=storage_options,
#    3568 )
#
# File c:\Users\Botelho\anaconda3\lib\site-packages\pandas\io\formats\format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1159     created_buffer = False
#    1161 csv_formatter = CSVFormatter(
#    1162     path_or_buf=path_or_buf,
#    1163     line_terminator=line_terminator,
#    (...)
#    1178     formatter=self.fmt,
#    1179 )
# -> 1180 csv_formatter.save()
#    1182 if created_buffer:
#    1183     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\Botelho\anaconda3\lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.line_terminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File c:\Users\Botelho\anaconda3\lib\site-packages\pandas\io\common.py:697, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     695 # Only for write methods
#     696 if "r" not in mode and is_path:
# --> 697     check_parent_directory(str(handle))
#     699 if compression:
#     700     if compression != "zstd":
#     701         # compression libraries do not like an explicit text-mode
#
# File c:\Users\Botelho\anaconda3\lib\site-packages\pandas\io\common.py:571, in check_parent_directory(path)
#     569 parent = Path(path).parent
#     570 if not parent.is_dir():
# --> 571     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'data'

# %%
link = 'https://liquipedia.net/counterstrike/ESL/One/2019/Cologne'
page = requests.get(link)
soup = BeautifulSoup(page.content)
pd.read_html(page.content)[11]
# Out:
#    0        1
# 0  1    KRIMZ
# 1  2       JW
# 2  3     Xizt
# 3  4    twist
# 4  5  Brollan
# 5  C    Jumpy
