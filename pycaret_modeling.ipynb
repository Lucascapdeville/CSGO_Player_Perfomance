# %% [markdown]
# # Pycaret modeling

# %%
import pandas as pd
from pycaret.regression import *

# %%
players_stats = pd.read_csv('data/players_stats.csv' ,sep=';')

# %%
players_stats
# Out:
#           id    player  player_team  s1 opponent  s2  rating2.0   map  \
# 0      11893     zywoo     Vitality  10  AVANGAR  16       1.04    d2
# 1      11893     zywoo     Vitality  16  AVANGAR  11       1.63   inf
# 2      11893     zywoo     Vitality   9  AVANGAR  16       0.90   mrg
# 3      11893     zywoo     Vitality  16     MOUZ  10       1.52   mrg
# 4      11893     zywoo     Vitality  16     MOUZ   5       1.44   vtg
# ...      ...       ...          ...  ..      ...  ..        ...   ...
# 42981  13461  wannafly  Lucid Dream  16     NASR   1       1.17    d2
# 42982  13461  wannafly  Lucid Dream  16     NASR   9       1.60  nuke
# 42983  13461  wannafly  Lucid Dream   8     NASR  16       0.79   ovp
# 42984  13461  wannafly  Lucid Dream  16   Entity   1       1.23   mrg
# 42985  13461  wannafly  Lucid Dream  16   Entity   5       1.54  nuke
#
#              date event_type event_tier  team_rank  opponent_rank  \
# ...

# %%
#players_stats.drop(['date','opponent','player','player_team'],axis = 1,inplace = True)

# %%
players_stats = players_stats.astype({'id':str})

# %%
players_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42986 entries, 0 to 42985
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                42986 non-null  object
#  1   player            42986 non-null  object
#  2   player_team       42986 non-null  object
#  3   s1                42986 non-null  int64
#  4   opponent          42986 non-null  object
#  5   s2                42986 non-null  int64
#  6   rating2.0         42986 non-null  float64
#  7   map               42986 non-null  object
#  8   date              42986 non-null  object
#  9   event_type        42986 non-null  object
#  10  event_tier        42986 non-null  object
#  11  team_rank         42986 non-null  float64
#  12  opponent_rank     42986 non-null  float64
#  13  rank_difference   42986 non-null  float64
#  14  favorite          42986 non-null  bool
#  15  round_difference  42986 non-null  int64
# ...

# %% [markdown]
# # General model

# %%
model = setup(data = players_stats.drop(['id','date','player','opponent'],axis=1),target='rating2.0',session_id=42,normalize=True)
# Out:
# <style type="text/css">
# #T_97265_row27_col1, #T_97265_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_97265">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97265_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_97265_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97265_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97265_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_97265_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_97265_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_97265_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_97265_row1_col1" class="data row1 col1" >rating2.0</td>
#     </tr>
#     <tr>
#       <th id="T_97265_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_a1fea th {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
save_model(best,'rating_pred')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='rating2.0',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strate...
#                   ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0,
#                                       criterion='mse', max_depth=None,
#                                       max_features='auto', max_leaf_nodes=None,
# ...
